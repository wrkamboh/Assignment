# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Write your code here
name = "wajahat"
father = "Aslam"
DOB = "7th July"

print(name)
print(father)
print(DOB)
# Out:
# wajahat
# Aslam
# 7th July

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here


age = 22
city = "Karachi"
is_student = True


print("--- My Bio ---")
print("Name: " + name)
print("Father Name: " + father)
print("Age:", age)
print("City:", city)
print("Saylani Python Crash Course Student?:", is_student)
# Out:
# --- My Bio ---
# Name: wajahat
# Father Name: Aslam
# Age: 22
# City: Karachi
# Saylani Python Crash Course Student?: True

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here

a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division decimal:", a / b)
print("Division:", a // b)
print("Modulus:", a % b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division decimal: 3.3333333333333335
# Division: 3
# Modulus: 1

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here


english = 85
islamiat = 92
maths = 78

total_marks = 300

obtained_marks = english + islamiat + maths

percentage = (obtained_marks / total_marks) * 100


print("--- Result Card ---")
print("English Marks:", english)
print("Islamiat Marks:", islamiat)
print("Maths Marks:", maths)
print("-------------------")
print("Obtained Marks:", obtained_marks)
print("Total Marks:", total_marks)
print("Percentage:", percentage,"%")
# Out:
# --- Result Card ---
# English Marks: 85
# Islamiat Marks: 92
# Maths Marks: 78
# -------------------
# Obtained Marks: 255
# Total Marks: 300
# Percentage: 85.0 %
